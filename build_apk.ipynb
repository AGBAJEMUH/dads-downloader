# %% [markdown]
# # Dad's Downloader APK Build
#
# **Instructions:**
# 1.  Ensure you have uploaded `app.py`, `buildozer.spec`, and `requirements.txt` to the file browser on the left.
# 2.  Run the cells below in order.

# %%
# 1. Install Buildozer and dependencies
# !pip install buildozer cython==0.29.33

# %%
# 2. Install System Dependencies (Linux)
# Using --fix-missing to ignore bad mirrors
# !sudo apt-get update --fix-missing
# !sudo apt-get install -y --fix-missing \
    python3-pip \
    build-essential \
    git \
    python3 \
    python3-dev \
    ffmpeg \
    libsdl2-dev \
    libsdl2-image-dev \
    libsdl2-mixer-dev \
    libsdl2-ttf-dev \
    libportmidi-dev \
    libswscale-dev \
    libavformat-dev \
    libavcodec-dev \
    zlib1g-dev \
    libgstreamer1.0 \
    gstreamer1.0-plugins-base \
    gstreamer1.0-plugins-good

# %%
# 3. Install Java (Required)
# !apt-get install -y openjdk-8-jdk
# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java

# %%
# 4. Build the APK
# This will take ~15 minutes. Type 'y' in the output if prompted for license agreement.
# !buildozer android debug
